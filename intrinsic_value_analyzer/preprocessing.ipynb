# %% [markdown]
# Intrinsic value analysis is about finding how much a stock is worth based on how much the company makes from its assets, then comparing that against the current stock price/valuation of the company to figure out if its over or undervalued.
